# %%
#1 uzdevums nolasa failus
with open(Data.txt, 'r') as f:
    my_list = [line.rstrip('\n') for line in f]

# %%
#2 zudevums
Dict["PYTHON"]=["python1.hmt", "python2.htm"]

document = open('LIWC_words.txt', 'r')
pythonfile = document.read()
pylist = {}
for line in pylist:
    k, v = line.strip().split(' ')
    answer[k.strip()] = v.strip()

pythonfile.close()

# %%
#3 zudevums
Dict["PYTHON"]=["python1.htm","python2.htm"]
for Dict in Dict:
    print(Dict, end=", ")
print("\b\b", end="")
print(" ")
# Out:
# Apple, Banana, Plum, Orange,
